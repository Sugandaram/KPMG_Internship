# %% [markdown]
# ### Task 1
#
# # Data Quality Assessment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
main_data = pd.ExcelFile("KPMG_VI_New_raw_data_update_final.xlsx")

# %%
TRS = pd.read_excel(main_data, "Transactions", header = None)
NCL = pd.read_excel(main_data, "NewCustomerList", header = None)
CDG = pd.read_excel(main_data, "CustomerDemographic", header = None)
CA = pd.read_excel(main_data, "CustomerAddress", header = None)

# %%
TRS.columns = TRS.loc[1].values.tolist()
NCL.columns = NCL.loc[1].values.tolist()
CDG.columns = CDG.loc[1].values.tolist()
CA.columns = CA.loc[1].values.tolist()



TRS.drop([0,1], inplace = True)
NCL.drop([0,1], inplace = True)
CDG.drop([0,1], inplace = True)
CA.drop([0,1], inplace = True)

# %%
NCL = NCL.loc[:, NCL.columns.notnull()]

# %%
TRS.head()
# Out:
#   transaction_id product_id customer_id     transaction_date online_order  \
# 2              1          2        2950  2017-02-25 00:00:00        False
# 3              2          3        3120  2017-05-21 00:00:00         True
# 4              3         37         402  2017-10-16 00:00:00        False
# 5              4         88        3135  2017-08-31 00:00:00        False
# 6              5         78         787  2017-10-01 00:00:00         True
#
#   order_status           brand product_line product_class product_size  \
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved      OHM Cycles     Standard           low       medium
# 5     Approved  Norco Bicycles     Standard        medium       medium
# 6     Approved  Giant Bicycles     Standard        medium        large
#
#   list_price standard_cost product_first_sold_date
# ...

# %%
TRS.describe()
# Out:
#         transaction_id  product_id  customer_id     transaction_date  \
# count            20000       20000        20000                20000
# unique           20000         101         3494                  364
# top                  1           0         2183  2017-02-14 00:00:00
# freq                 1        1378           14                   82
#
#        online_order order_status  brand product_line product_class  \
# count         19640        20000  19803        19803         19803
# unique            2            2      6            4             3
# top            True     Approved  Solex     Standard        medium
# freq           9829        19821   4253        14176         13826
#
#        product_size  list_price  standard_cost  product_first_sold_date
# count         19803    20000.00       19803.00                    19803
# unique            3      296.00         103.00                      100
# ...

# %%
TRS.product_class.value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
TRS.shape
# Out:
# (20000, 13)

# %%
CA.head()
# Out:
#   customer_id              address postcode            state    country  \
# 2           1   060 Morning Avenue     2016  New South Wales  Australia
# 3           2  6 Meadow Vale Court     2153  New South Wales  Australia
# 4           4   0 Holy Cross Court     4211              QLD  Australia
# 5           5  17979 Del Mar Point     2448  New South Wales  Australia
# 6           6     9 Oakridge Court     3216              VIC  Australia
#
#   property_valuation
# 2                 10
# 3                 10
# 4                  9
# 5                  4
# 6                  9

# %%
CA.describe()
# Out:
#         customer_id                  address  postcode state    country  \
# count          3999                     3999      3999  3999       3999
# unique         3999                     3996       873     5          1
# top               1  3 Mariners Cove Terrace      2170   NSW  Australia
# freq              1                        2        31  2054       3999
#
#         property_valuation
# count                 3999
# unique                  12
# top                      9
# freq                   647

# %%
CDG.head()
# Out:
#   customer_id      first_name  last_name  gender  \
# 2           1         Laraine  Medendorp       F
# 3           2             Eli    Bockman    Male
# 4           3           Arlin     Dearle    Male
# 5           4          Talbot        NaN    Male
# 6           5  Sheila-kathryn     Calton  Female
#
#   past_3_years_bike_related_purchases                  DOB  \
# 2                                  93  1953-10-12 00:00:00
# 3                                  81  1980-12-16 00:00:00
# 4                                  61  1954-01-20 00:00:00
# 5                                  33  1961-10-03 00:00:00
# 6                                  56  1977-05-13 00:00:00
#
#                 job_title job_industry_category     wealth_segment  \
# 2     Executive Secretary                Health      Mass Customer
# 3  Administrative Officer    Financial Services      Mass Customer
# 4      Recruiting Manager              Property      Mass Customer
# ...

# %%
CDG.describe()
# Out:
#         customer_id first_name last_name  gender  \
# count          4000       4000      3875    4000
# unique         4000       3139      3725       6
# top               1        Max  Pristnor  Female
# freq              1          5         3    2037
#
#         past_3_years_bike_related_purchases                  DOB  \
# count                                  4000                 3913
# unique                                  100                 3448
# top                                      16  1978-01-30 00:00:00
# freq                                     56                    7
#
#                                    job_title job_industry_category  \
# count                                   3494                  3344
# unique                                   195                     9
# top     Business Systems Development Analyst         Manufacturing
# freq                                      45                   799
#
# ...

# %%
CDG.gender.unique()
# Out:
# array(['F', 'Male', 'Female', 'U', 'Femal', 'M'], dtype=object)

# %%
CDG["gender"].replace({"M":"Male", "F": "Female", "Femal": "Female"}, inplace = True)

# %%
CDG.gender.unique()
# Out:
# array(['Female', 'Male', 'U'], dtype=object)

# %%
CDG.drop(["default"],axis =1, inplace = True)

# %%
CDG.head()
# Out:
#   customer_id      first_name  last_name  gender  \
# 2           1         Laraine  Medendorp  Female
# 3           2             Eli    Bockman    Male
# 4           3           Arlin     Dearle    Male
# 5           4          Talbot        NaN    Male
# 6           5  Sheila-kathryn     Calton  Female
#
#   past_3_years_bike_related_purchases                  DOB  \
# 2                                  93  1953-10-12 00:00:00
# 3                                  81  1980-12-16 00:00:00
# 4                                  61  1954-01-20 00:00:00
# 5                                  33  1961-10-03 00:00:00
# 6                                  56  1977-05-13 00:00:00
#
#                 job_title job_industry_category     wealth_segment  \
# 2     Executive Secretary                Health      Mass Customer
# 3  Administrative Officer    Financial Services      Mass Customer
# 4      Recruiting Manager              Property      Mass Customer
# ...

# %%
NCL.head()
# Out:
#   first_name  last_name  gender past_3_years_bike_related_purchases  \
# 2    Chickie    Brister    Male                                  86
# 3      Morly     Genery    Male                                  69
# 4    Ardelis  Forrester  Female                                  10
# 5     Lucine      Stutt  Female                                  64
# 6    Melinda     Hadlee  Female                                  34
#
#                    DOB                   job_title job_industry_category  \
# 2           1957-07-12             General Manager         Manufacturing
# 3           1970-03-22         Structural Engineer              Property
# 4  1974-08-28 00:00:00      Senior Cost Accountant    Financial Services
# 5           1979-01-28  Account Representative III         Manufacturing
# 6           1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car tenure              address  \
# ...

# %%
NCL.describe()
# Out:
#        first_name last_name  gender past_3_years_bike_related_purchases  \
# count        1000       971    1000                                1000
# unique        940       961       3                                 100
# top      Rozamond    Sissel  Female                                  60
# freq            3         2     513                                  20
#
#                DOB            job_title job_industry_category wealth_segment  \
# count          983                  894                   835           1000
# unique         961                  184                     9              3
# top     1965-07-03  Associate Professor    Financial Services  Mass Customer
# freq             2                   15                   203            508
#
#        deceased_indicator owns_car  tenure           address postcode state  \
# count                1000     1000    1000              1000     1000  1000
# ...

# %%
NCL.gender.unique()
# Out:
# array(['Male', 'Female', 'U'], dtype=object)
